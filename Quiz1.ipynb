# %% [markdown]
# # Quiz 1

# %%
num_of_character = 3
character_to_print = "-"

for i in range(num_of_character):
    print(character_to_print, end="")
# Out:
# ---

# %%
from matplotlib.pyplot import plot
plot([1,2,3,4,], [2,2,3,3,])
